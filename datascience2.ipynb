# %%
import matplotlib.pyplot as plt

# %%
######### Machine learning #########

### Examples of graphs

# Y axis is the dependent variable and X axis is the independent variable
# So (x,y) is (independent, dependent)import matplotlib.pyplot as plt
time_spent_walking = [1,2,3,4,5]
distance]2,4,6,8,10]
plt.plot(time_spent_walking, distance)
# Out:
#   File "<ipython-input-4-a16c3aeffded>", line 8
#     distance]2,4,6,8,10]
#             ^
# SyntaxError: unmatched ']'

# %%
car_age = [1,2,5,10,30]
price = [30000,25000,18000,10000,4000]
plt.plot(car_age,price)

# %%
study_time = [1,5,10,20,50,80]
test_score_results = [40,60,70,75,88,93]
plt.plot(study_time,test_score_results)

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]

# %%
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Graph to show the effect of X on y')
plt.plot(x,y)
plt.show()

# %%
#Example
'''id the dependent and independent variables
'''
ad_budget = [1,10,50,100,1000] # x axis
sales = [10,100,500,1000,10000] # y axis
plt.xlabel('Amount($) spent on FB ads')
plt.ylabel('Amount of sales($)')
plt.title('Cost of FB ads vs Sales')
plt.plot(ad_budget,sales)
